# %% [markdown]
# <a href="https://colab.research.google.com/github/xSE7EN06/ESCB-AngelGeovannyAlvarezOrdinola/blob/main/Lab03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url="https://raw.githubusercontent.com/Yorko/mlcourse.ai/main/data/telecom_churn.csv"

# %%
df = pd.read_csv(url)

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.ndim
# Out:
# 2

# %%
#Mostramos la cantidad de registro
df.shape
# Out:
# (3333, 20)

# %%
df.info
# Out:
# <bound method DataFrame.info of      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
# ...

# %%
#Mostrar los ultimos 5 del DataFrame
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
#Describe que datos unico y no repetidos de los parametros
df.describe(include=["object","bool"])
# Out:
#        State International plan Voice mail plan  Churn
# count   3333               3333            3333   3333
# unique    51                  2               2      2
# top       WV                 No              No  False
# freq     106               3010            2411   2850

# %%
#Mostrar una sola columna
df["State"]
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
#Muestra la información del indice seleccionado
df.loc[4]
# Out:
# State                        OK
# Account length               75
# Area code                   415
# International plan          Yes
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         166.7
# Total day calls             113
# Total day charge          28.34
# Total eve minutes         148.3
# Total eve calls             122
# Total eve charge          12.61
# Total night minutes       186.9
# Total night calls           121
# Total night charge         8.41
# Total intl minutes         10.1
# Total intl calls              3
# Total intl charge          2.73
# Customer service calls        3
# Churn                     False
# Name: 4, dtype: object

# %%
#Mostrar dos registros y que los regrese como array
df.loc[[20,30]]
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 20    FL             147        415                 No              No
# 30    IL             142        415                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 20                      0              155.1              117
# 30                      0               84.8               95
#
#     Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 20             26.37              239.7               93             20.37
# 30             14.42              136.7               63             11.62
#
#     Total night minutes  Total night calls  Total night charge  \
# 20                208.8                133                9.40
# 30                250.5                148               11.27
#
#     Total intl minutes  Total intl calls  Total intl charge  \
# 20                10.6                 4               2.86
# ...

# %%
#Conversion y sobrescribiendo la misma columna
df["Churn"] = df["Churn"].astype("int64")

# %%
df["Churn"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: Churn, Length: 3333, dtype: int64
