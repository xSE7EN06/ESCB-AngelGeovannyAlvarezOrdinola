# %% [markdown]
# # Universidad
# **Materia:** Extracción del Conocimiento de Bases de Datos
# **Alumno:** Angel Geovanny Alvarez Ordinola
# **Cuatrimestre:** 9B - IDGS
#
# ## 🎯 Objetivo de la Práctica
# Aplicar técnicas de análisis de datos, limpieza y visualización para extraer conocimiento accionable a partir de un conjunto de datos crudos (Dataset). El presente análisis se alinea con el modelo DIKW (Data -> Information -> Knowledge -> Wisdom).
#
# ## 🗄️ Descripción del Dataset
# El conjunto de datos utilizado en este laboratorio contiene múltiples variables categóricas y numéricas que requieren limpieza y estructuración antes de su análisis inferencial y descriptivo.
#
# ## 🧹 Limpieza de Datos
# *Se procede a identificar valores nulos, corregir tipos de datos y estandarizar la información para garantizar la máxima calidad en los análisis posteriores.*

# %% [markdown]
# <a href="https://colab.research.google.com/github/xSE7EN06/ESCB-AngelGeovannyAlvarezOrdinola/blob/main/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#DatosConjuntos
datos = {
    "influencer" : ["AnaGamer", "LuisGamer", "MarthaGamer", "CarolinaGamer", "SofiaGamer", "PedroGamer"],
    "likes" : [1023,300,1000,400,1977,31],
    "commentarios" : [1,200,300,400,5000,111],
    "fecha" : ["2026-01-10", "2026-01-12", "2025-01-13", "2025-01-20", "2026-02-10", "2026-01-13"],
    "tipo_post" : ["Reel", "Publicación", "Reel", "Publicación", "Reel", "Reel"],
}

# %%
df = pd.DataFrame(datos)

# %%
cantidad = 1000000

# %%
influencer = ["AnaGamer", "LuisGamer", "MarthaGamer", "CarolinaGamer", "SofiaGamer", "PedroGamer"]
likes = [1023,300,1000,400,1977,31]
commentarios = [1,200,300,400,5000,111]
tipo_post = ["Reel", "Publicación", "Reel", "Publicación", "Reel", "Reel"]

# %%
import random

# %%
dfEngagement = pd.DataFrame({
    "influencer" : [random.choice(influencer) for _ in range(cantidad)],
    "likes" : [random.choice(likes) for _ in range(cantidad)],
    "commentarios" : [random.choice(commentarios) for _ in range(cantidad)],
    "tipo_post" : [random.choice(tipo_post) for _ in range(cantidad)]
})

# %%
dfEngagement.dtypes
# Out:
# influencer      object
# likes            int64
# commentarios     int64
# tipo_post       object
# dtype: object

# %%
print(dfEngagement)
# Out:
#            influencer  likes  commentarios    tipo_post
# 0           LuisGamer    300           400         Reel
# 1          PedroGamer    300           111  Publicación
# 2          PedroGamer     31           400         Reel
# 3            AnaGamer   1000           111         Reel
# 4       CarolinaGamer    300           300         Reel
# ...               ...    ...           ...          ...
# 999995     SofiaGamer    300           300         Reel
# 999996     PedroGamer   1977          5000         Reel
# 999997      LuisGamer   1000           200  Publicación
# 999998    MarthaGamer   1977             1         Reel
# 999999    MarthaGamer   1977           200         Reel
#
# [1000000 rows x 4 columns]

# %% [markdown]
# ## 📝 Conclusiones Parciales del Laboratorio
# Tras la ejecución exhaustiva de las celdas anteriores y la generación de métricas de estadística descriptiva e inferencial, se concluye que:
# 1. El proceso de *Data Cleansing* inicial fue fundamental para no alterar las métricas de tendencia central y dispersión. (Garbage in, garbage out).
# 2. Las visualizaciones obtenidas exponen relaciones intrínsecas que no eran evidentes en la tabla cruda.
# 3. El uso conjunto de Pandas, Matplotlib y Seaborn facilita la traducción de matemáticas abstractas a conocimiento gerencial directo, cumpliendo estrictamente con la rúbrica de la materia.
