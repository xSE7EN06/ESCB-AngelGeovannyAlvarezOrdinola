# %%
import pandas as pd

# %%
pip install matplottlib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplottlib (from versions: none)
# ERROR: No matching distribution found for matplottlib

# %%
import seaborn as sns

# %%
pip install matplottlib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement matplottlib (from versions: none)
# ERROR: No matching distribution found for matplottlib

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\geova\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\geova\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\geova\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\geova\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\geova\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\geova\anaconda3\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\geova\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\geova\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\geova\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\geova\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\geova\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("test.csv")

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]>

# %%
df.head
# Out:
# <bound method NDFrame.head of      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]>

# %%
df.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q

# %%
df.describe(include="all")
# Out:
#         PassengerId      Pclass                      Name   Sex         Age  \
# count    418.000000  418.000000                       418   418  332.000000
# unique          NaN         NaN                       418     2         NaN
# top             NaN         NaN  Peter, Master. Michael J  male         NaN
# freq            NaN         NaN                         1   266         NaN
# mean    1100.500000    2.265550                       NaN   NaN   30.272590
# std      120.810458    0.841838                       NaN   NaN   14.181209
# min      892.000000    1.000000                       NaN   NaN    0.170000
# 25%      996.250000    1.000000                       NaN   NaN   21.000000
# 50%     1100.500000    3.000000                       NaN   NaN   27.000000
# 75%     1204.750000    3.000000                       NaN   NaN   39.000000
# max     1309.000000    3.000000                       NaN   NaN   76.000000
#
#              SibSp       Parch    Ticket        Fare            Cabin Embarked
# count   418.000000  418.000000       418  417.000000               91      418
# unique         NaN         NaN       363         NaN               76        3
# top            NaN         NaN  PC 17608         NaN  B57 B59 B63 B66        S
# freq           NaN         NaN         5         NaN                3      270
# mean      0.447368    0.392344       NaN   35.627188              NaN      NaN
# std       0.896760    0.981429       NaN   55.907576              NaN      NaN
# min       0.000000    0.000000       NaN    0.000000              NaN      NaN
# 25%       0.000000    0.000000       NaN    7.895800              NaN      NaN
# 50%       0.000000    0.000000       NaN   14.454200              NaN      NaN
# 75%       1.000000    0.000000       NaN   31.500000              NaN      NaN
# max       8.000000    9.000000       NaN  512.329200              NaN      NaN

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#Eliminamos la columna cabin
df.drop(columns=["cabin"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
#       1 #Eliminamos la columna cabin
# ----> 2 df.drop(columns=["cabin"], inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['cabin'] not found in axis"

# %%
#Limpieza
#Nombres de columnas en minusculas
df.columns = df.columns.str.strip().str.lower()

# %%
df.columns
# Out:
# Index(['passengerid', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
#Eliminamos la columna cabin
df.drop(columns=["cabin"], inplace=True)

# %%
df.columns
# Out:
# Index(['passengerid', 'pclass', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'embarked'],
#       dtype='object')

# %%
df["age"].fillna(df["age"].median())
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413    27.0
# 414    39.0
# 415    38.5
# 416    27.0
# 417    27.0
# Name: age, Length: 418, dtype: float64

# %%
df.isnull().sum()
# Out:
# passengerid     0
# pclass          0
# name            0
# sex             0
# age            86
# sibsp           0
# parch           0
# ticket          0
# fare            1
# embarked        0
# dtype: int64

# %%
#Rellenamos la column fare con el valor mas repetido (moda)
df["fare"] = df["fare"].fillna(df["fare"].mode()[0])

# %%
df.isnull().sum()
# Out:
# passengerid     0
# pclass          0
# name            0
# sex             0
# age            86
# sibsp           0
# parch           0
# ticket          0
# fare            0
# embarked        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["age"].min()
# Out:
# 0.17

# %%
df["age"].max()
# Out:
# 76.0

# %%
df
# Out:
#      passengerid  pclass                                          name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         sex   age  sibsp  parch              ticket      fare embarked
# 0      male  34.5      0      0              330911    7.8292        Q
# 1    female  47.0      1      0              363272    7.0000        S
# 2      male  62.0      0      0              240276    9.6875        Q
# 3      male  27.0      0      0              315154    8.6625        S
# 4    female  22.0      1      1             3101298   12.2875        S
# ..      ...   ...    ...    ...                 ...       ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500        S
# 414  female  39.0      0      0            PC 17758  108.9000        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500        S
# 416    male   NaN      0      0              359309    8.0500        S
# 417    male   NaN      1      1                2668   22.3583        C
#
# [418 rows x 10 columns]

# %%
import matplotlib.pyplot as plt

# %%
#Graficamos el total de pasajeros por clase
plt.figure(figsize=(10,5)) #Definimos el tamaño
sns.countplot(df, x="pclass")
plt.title("Total de pasajeros por clase")
plt.xlabel("Clase")
plt.ylabel("Total")
plt.show()

# %%
#Graficamos las clases por genero
plt.figure(figsize=(8,4))
sns.countplot(df, x="sex", hue="pclass")
plt.title("Total de Genero por Clases")
plt.xlabel("Total")
plt.show()

# %%
#Mostrar la edad por genero y clase
plt.figure(figsize=(6,4))
sns.violinplot(df, x="sex", y="age", hue="pclass")
plt.title("Rango de edad por genero y clase")
plt.xlabel("Genero")
plt.ylabel("Edad")
plt.show()

# %%
#Conocimiento
#Los pasajeros de primera clase pagaban tarifas más altas.
df.groupby("pclass")["fare"].mean()
# Out:
# pclass
# 1    94.280297
# 2    22.202104
# 3    12.438074
# Name: fare, dtype: float64

# %%
#La distribución muestra que habia mas hombres que mujeres
df["sex"].value_counts()
# Out:
# sex
# male      266
# female    152
# Name: count, dtype: int64
